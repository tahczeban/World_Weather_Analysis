# %%
# Import the random module.
import random
# Import timeit.
import timeit
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the API key.
import sys
import config
from config import weather_api_key
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d8b7bcac9ec171d9c686079be9f2233

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Print the city count to confirm sufficient count
print("{} cities have been identified to poll for weather".format(len(cities)))
# Out:
# 0 cities have been identified to poll for weather

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | yar-sale
# Processing Record 3 of Set 1 | tuktoyaktuk
# Processing Record 4 of Set 1 | carnarvon
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 1 | vanimo
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | yangambi
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | aklavik
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | bethel
# Processing Record 14 of Set 1 | wewak
# Processing Record 15 of Set 1 | camacha
# Processing Record 16 of Set 1 | bengkulu
# Processing Record 17 of Set 1 | yekaterinovka
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | thompson
# Processing Record 21 of Set 1 | shingu
# Processing Record 22 of Set 1 | tarancon
# Processing Record 23 of Set 1 | mehamn
# Processing Record 24 of Set 1 | hidrolandia
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | college
# Processing Record 27 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 1 | norman wells
# Processing Record 29 of Set 1 | ocampo
# Processing Record 30 of Set 1 | haines junction
# Processing Record 31 of Set 1 | kholodnyy
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | windsor
# Processing Record 34 of Set 1 | waingapu
# Processing Record 35 of Set 1 | dikson
# Processing Record 36 of Set 1 | kuah
# Processing Record 37 of Set 1 | bandarbeyla
# Processing Record 38 of Set 1 | tevriz
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | kyra
# Processing Record 41 of Set 1 | puerto escondido
# Processing Record 42 of Set 1 | hun
# Processing Record 43 of Set 1 | tyrma
# Processing Record 44 of Set 1 | airai
# Processing Record 45 of Set 1 | lingao
# Processing Record 46 of Set 1 | buala
# Processing Record 47 of Set 1 | morehead
# Processing Record 48 of Set 1 | ribeira grande
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | sonoita
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | asau
# Processing Record 3 of Set 2 | yirol
# City not found. Skipping...
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | leningradskiy
# Processing Record 6 of Set 2 | sangar
# Processing Record 7 of Set 2 | chokurdakh
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 2 | turukhansk
# Processing Record 11 of Set 2 | new norfolk
# Processing Record 12 of Set 2 | hilo
# Processing Record 13 of Set 2 | seoul
# Processing Record 14 of Set 2 | tuatapere
# Processing Record 15 of Set 2 | micheweni
# Processing Record 16 of Set 2 | zunyi
# Processing Record 17 of Set 2 | hithadhoo
# Processing Record 18 of Set 2 | upernavik
# Processing Record 19 of Set 2 | cabo san lucas
# Processing Record 20 of Set 2 | esperance
# Processing Record 21 of Set 2 | coquimbo
# Processing Record 22 of Set 2 | tambul
# City not found. Skipping...
# Processing Record 23 of Set 2 | sofiysk
# City not found. Skipping...
# Processing Record 24 of Set 2 | tarko-sale
# Processing Record 25 of Set 2 | grimari
# City not found. Skipping...
# Processing Record 26 of Set 2 | mataura
# Processing Record 27 of Set 2 | east london
# Processing Record 28 of Set 2 | anahuac
# Processing Record 29 of Set 2 | aksha
# Processing Record 30 of Set 2 | sao filipe
# Processing Record 31 of Set 2 | kirovskiy
# Processing Record 32 of Set 2 | hasaki
# Processing Record 33 of Set 2 | north branch
# Processing Record 34 of Set 2 | miyako
# Processing Record 35 of Set 2 | barrow
# Processing Record 36 of Set 2 | opuwo
# Processing Record 37 of Set 2 | khatanga
# Processing Record 38 of Set 2 | zhigansk
# Processing Record 39 of Set 2 | lebu
# Processing Record 40 of Set 2 | saint-philippe
# Processing Record 41 of Set 2 | luderitz
# Processing Record 42 of Set 2 | albany
# Processing Record 43 of Set 2 | busselton
# Processing Record 44 of Set 2 | kavieng
# Processing Record 45 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 2 | gamba
# Processing Record 47 of Set 2 | taltal
# Processing Record 48 of Set 2 | pishin
# Processing Record 49 of Set 2 | lata
# Processing Record 50 of Set 2 | anadyr
# Processing Record 1 of Set 3 | lompoc
# Processing Record 2 of Set 3 | rusape
# Processing Record 3 of Set 3 | torbay
# Processing Record 4 of Set 3 | lorengau
# Processing Record 5 of Set 3 | sur
# Processing Record 6 of Set 3 | rundu
# Processing Record 7 of Set 3 | ponta do sol
# Processing Record 8 of Set 3 | trairi
# Processing Record 9 of Set 3 | chabahar
# Processing Record 10 of Set 3 | pafos
# Processing Record 11 of Set 3 | mar del plata
# Processing Record 12 of Set 3 | nouadhibou
# Processing Record 13 of Set 3 | rawson
# Processing Record 14 of Set 3 | goderich
# Processing Record 15 of Set 3 | cayenne
# Processing Record 16 of Set 3 | urumqi
# Processing Record 17 of Set 3 | ancud
# Processing Record 18 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 3 | hobart
# Processing Record 20 of Set 3 | mahebourg
# Processing Record 21 of Set 3 | adrar
# Processing Record 22 of Set 3 | nueva helvecia
# Processing Record 23 of Set 3 | shanghai
# Processing Record 24 of Set 3 | ballina
# Processing Record 25 of Set 3 | kahului
# Processing Record 26 of Set 3 | san patricio
# Processing Record 27 of Set 3 | rocha
# Processing Record 28 of Set 3 | sorland
# Processing Record 29 of Set 3 | sauk rapids
# Processing Record 30 of Set 3 | aksu
# Processing Record 31 of Set 3 | mercedes
# Processing Record 32 of Set 3 | bac lieu
# Processing Record 33 of Set 3 | yeppoon
# Processing Record 34 of Set 3 | pevek
# Processing Record 35 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 3 | grindavik
# Processing Record 37 of Set 3 | isangel
# Processing Record 38 of Set 3 | bredasdorp
# Processing Record 39 of Set 3 | mwinilunga
# Processing Record 40 of Set 3 | dingle
# Processing Record 41 of Set 3 | makasar
# Processing Record 42 of Set 3 | faanui
# Processing Record 43 of Set 3 | tasiilaq
# Processing Record 44 of Set 3 | smolenka
# Processing Record 45 of Set 3 | north platte
# Processing Record 46 of Set 3 | strezhevoy
# Processing Record 47 of Set 3 | ginda
# Processing Record 48 of Set 3 | ustikolina
# Processing Record 49 of Set 3 | bathsheba
# Processing Record 50 of Set 3 | bluff
# Processing Record 1 of Set 4 | kodiak
# Processing Record 2 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 4 | jieshi
# Processing Record 4 of Set 4 | byron bay
# Processing Record 5 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 4 | xudat
# Processing Record 7 of Set 4 | cananeia
# Processing Record 8 of Set 4 | castro
# Processing Record 9 of Set 4 | shache
# Processing Record 10 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 4 | pacific grove
# Processing Record 12 of Set 4 | chirongui
# Processing Record 13 of Set 4 | teplodar
# Processing Record 14 of Set 4 | lashio
# Processing Record 15 of Set 4 | los llanos de aridane
# Processing Record 16 of Set 4 | laredo
# Processing Record 17 of Set 4 | lervik
# Processing Record 18 of Set 4 | makakilo city
# Processing Record 19 of Set 4 | chipinge
# Processing Record 20 of Set 4 | saint george
# Processing Record 21 of Set 4 | springbok
# Processing Record 22 of Set 4 | cherskiy
# Processing Record 23 of Set 4 | kimbe
# Processing Record 24 of Set 4 | mount gambier
# Processing Record 25 of Set 4 | bronnoysund
# Processing Record 26 of Set 4 | guayaramerin
# Processing Record 27 of Set 4 | aykhal
# Processing Record 28 of Set 4 | shasta lake
# Processing Record 29 of Set 4 | broome
# Processing Record 30 of Set 4 | sadasivpet
# Processing Record 31 of Set 4 | joensuu
# Processing Record 32 of Set 4 | tiksi
# Processing Record 33 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 34 of Set 4 | atyrau
# Processing Record 35 of Set 4 | dzilam gonzalez
# Processing Record 36 of Set 4 | skoczow
# Processing Record 37 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 4 | alytus
# Processing Record 39 of Set 4 | tecoanapa
# Processing Record 40 of Set 4 | maldonado
# Processing Record 41 of Set 4 | mount isa
# Processing Record 42 of Set 4 | uva
# Processing Record 43 of Set 4 | machico
# Processing Record 44 of Set 4 | maniitsoq
# Processing Record 45 of Set 4 | koygorodok
# Processing Record 46 of Set 4 | lavrentiya
# Processing Record 47 of Set 4 | katobu
# Processing Record 48 of Set 4 | andevoranto
# City not found. Skipping...
# Processing Record 49 of Set 4 | san andres
# Processing Record 50 of Set 4 | chuy
# Processing Record 1 of Set 5 | helong
# Processing Record 2 of Set 5 | wau
# Processing Record 3 of Set 5 | fuling
# Processing Record 4 of Set 5 | los negros
# Processing Record 5 of Set 5 | atambua
# Processing Record 6 of Set 5 | general pico
# Processing Record 7 of Set 5 | choszczno
# Processing Record 8 of Set 5 | birao
# Processing Record 9 of Set 5 | hualmay
# Processing Record 10 of Set 5 | matadi
# Processing Record 11 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 5 | naze
# Processing Record 13 of Set 5 | quebo
# Processing Record 14 of Set 5 | corinto
# Processing Record 15 of Set 5 | quelimane
# Processing Record 16 of Set 5 | vaini
# Processing Record 17 of Set 5 | kamina
# Processing Record 18 of Set 5 | uryupinsk
# Processing Record 19 of Set 5 | sharjah
# Processing Record 20 of Set 5 | namatanai
# Processing Record 21 of Set 5 | the valley
# Processing Record 22 of Set 5 | deputatskiy
# Processing Record 23 of Set 5 | ust-tarka
# Processing Record 24 of Set 5 | arraial do cabo
# Processing Record 25 of Set 5 | changde
# Processing Record 26 of Set 5 | paiho
# City not found. Skipping...
# Processing Record 27 of Set 5 | kudahuvadhoo
# Processing Record 28 of Set 5 | santa cruz
# Processing Record 29 of Set 5 | oga
# Processing Record 30 of Set 5 | yalta
# Processing Record 31 of Set 5 | provideniya
# Processing Record 32 of Set 5 | mpika
# Processing Record 33 of Set 5 | jimma
# Processing Record 34 of Set 5 | kabompo
# Processing Record 35 of Set 5 | caravelas
# Processing Record 36 of Set 5 | lakatoro
# Processing Record 37 of Set 5 | unye
# City not found. Skipping...
# Processing Record 38 of Set 5 | derzhavinsk
# Processing Record 39 of Set 5 | san quintin
# Processing Record 40 of Set 5 | srednekolymsk
# Processing Record 41 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 5 | benghazi
# Processing Record 43 of Set 5 | vila velha
# Processing Record 44 of Set 5 | tam ky
# Processing Record 45 of Set 5 | avarua
# Processing Record 46 of Set 5 | kruisfontein
# Processing Record 47 of Set 5 | georgetown
# Processing Record 48 of Set 5 | nikolskoye
# Processing Record 49 of Set 5 | paamiut
# Processing Record 50 of Set 5 | fairbanks
# Processing Record 1 of Set 6 | barrhead
# Processing Record 2 of Set 6 | mansa
# Processing Record 3 of Set 6 | sembe
# Processing Record 4 of Set 6 | cairns
# Processing Record 5 of Set 6 | ashland
# Processing Record 6 of Set 6 | zhoucheng
# Processing Record 7 of Set 6 | vila franca do campo
# Processing Record 8 of Set 6 | clyde river
# Processing Record 9 of Set 6 | sao jose da coroa grande
# Processing Record 10 of Set 6 | leshukonskoye
# Processing Record 11 of Set 6 | aksarka
# Processing Record 12 of Set 6 | pavlodar
# Processing Record 13 of Set 6 | ahumada
# City not found. Skipping...
# Processing Record 14 of Set 6 | launceston
# Processing Record 15 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 16 of Set 6 | soyo
# Processing Record 17 of Set 6 | umm lajj
# Processing Record 18 of Set 6 | vardo
# Processing Record 19 of Set 6 | marzuq
# Processing Record 20 of Set 6 | olinda
# Processing Record 21 of Set 6 | banda aceh
# Processing Record 22 of Set 6 | port elizabeth
# Processing Record 23 of Set 6 | mogzon
# Processing Record 24 of Set 6 | nome
# Processing Record 25 of Set 6 | pangody
# Processing Record 26 of Set 6 | bardiyah
# Processing Record 27 of Set 6 | bangui
# Processing Record 28 of Set 6 | suoyarvi
# Processing Record 29 of Set 6 | tres arroyos
# Processing Record 30 of Set 6 | wundanyi
# Processing Record 31 of Set 6 | nueva loja
# Processing Record 32 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 33 of Set 6 | marawi
# Processing Record 34 of Set 6 | port hawkesbury
# Processing Record 35 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 6 | taganak
# Processing Record 37 of Set 6 | beringovskiy
# Processing Record 38 of Set 6 | xinmin
# Processing Record 39 of Set 6 | santa isabel
# Processing Record 40 of Set 6 | mattru
# Processing Record 41 of Set 6 | yamada
# Processing Record 42 of Set 6 | saldanha
# Processing Record 43 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 44 of Set 6 | pa sang
# Processing Record 45 of Set 6 | vila
# Processing Record 46 of Set 6 | cibinong
# Processing Record 47 of Set 6 | katsuura
# Processing Record 48 of Set 6 | vallenar
# Processing Record 49 of Set 6 | tezu
# Processing Record 50 of Set 6 | ocos
# Processing Record 1 of Set 7 | arman
# Processing Record 2 of Set 7 | eureka
# Processing Record 3 of Set 7 | kousseri
# Processing Record 4 of Set 7 | gannan
# Processing Record 5 of Set 7 | howard springs
# Processing Record 6 of Set 7 | juegang
# Processing Record 7 of Set 7 | serenje
# Processing Record 8 of Set 7 | fortuna
# Processing Record 9 of Set 7 | atar
# Processing Record 10 of Set 7 | souillac
# Processing Record 11 of Set 7 | watertown
# Processing Record 12 of Set 7 | severo-kurilsk
# Processing Record 13 of Set 7 | nanortalik
# Processing Record 14 of Set 7 | kiama
# Processing Record 15 of Set 7 | constitucion
# Processing Record 16 of Set 7 | zvenigovo
# Processing Record 17 of Set 7 | tsumeb
# Processing Record 18 of Set 7 | sao paulo de olivenca
# Processing Record 19 of Set 7 | touros
# Processing Record 20 of Set 7 | buckeye
# Processing Record 21 of Set 7 | straumen
# Processing Record 22 of Set 7 | panaba
# Processing Record 23 of Set 7 | placido de castro
# Processing Record 24 of Set 7 | zhatay
# Processing Record 25 of Set 7 | providencia
# Processing Record 26 of Set 7 | olafsvik
# Processing Record 27 of Set 7 | chapais
# Processing Record 28 of Set 7 | oshawa
# Processing Record 29 of Set 7 | roma
# Processing Record 30 of Set 7 | great falls
# Processing Record 31 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 32 of Set 7 | mitsamiouli
# Processing Record 33 of Set 7 | soldatskiy
# City not found. Skipping...
# Processing Record 34 of Set 7 | klaksvik
# Processing Record 35 of Set 7 | salinas
# Processing Record 36 of Set 7 | anloga
# Processing Record 37 of Set 7 | namibe
# Processing Record 38 of Set 7 | hambantota
# Processing Record 39 of Set 7 | campbell river
# Processing Record 40 of Set 7 | marsaxlokk
# Processing Record 41 of Set 7 | iberia
# Processing Record 42 of Set 7 | walvis bay
# Processing Record 43 of Set 7 | guerrero negro
# Processing Record 44 of Set 7 | kanturk
# Processing Record 45 of Set 7 | miandrivazo
# Processing Record 46 of Set 7 | aleksandrovsk-sakhalinskiy
# Processing Record 47 of Set 7 | te anau
# Processing Record 48 of Set 7 | kaseda
# Processing Record 49 of Set 7 | ayan
# Processing Record 50 of Set 7 | dunedin
# Processing Record 1 of Set 8 | kisangani
# Processing Record 2 of Set 8 | teguise
# Processing Record 3 of Set 8 | mayna
# Processing Record 4 of Set 8 | mazyr
# Processing Record 5 of Set 8 | flinders
# Processing Record 6 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 7 of Set 8 | belmonte
# Processing Record 8 of Set 8 | salalah
# Processing Record 9 of Set 8 | raichur
# Processing Record 10 of Set 8 | geraldton
# Processing Record 11 of Set 8 | ende
# Processing Record 12 of Set 8 | wonthaggi
# Processing Record 13 of Set 8 | praya
# Processing Record 14 of Set 8 | qingquan
# Processing Record 15 of Set 8 | pucallpa
# Processing Record 16 of Set 8 | longyearbyen
# Processing Record 17 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 8 | lovozero
# Processing Record 19 of Set 8 | kuito
# Processing Record 20 of Set 8 | salym
# Processing Record 21 of Set 8 | palmer
# Processing Record 22 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 8 | yuryevets
# Processing Record 24 of Set 8 | musafirkhana
# Processing Record 25 of Set 8 | nago
# Processing Record 26 of Set 8 | margate
# Processing Record 27 of Set 8 | novoagansk
# Processing Record 28 of Set 8 | nantucket
# Processing Record 29 of Set 8 | narsaq
# Processing Record 30 of Set 8 | bijie
# Processing Record 31 of Set 8 | kenai
# Processing Record 32 of Set 8 | bonavista
# Processing Record 33 of Set 8 | manta
# Processing Record 34 of Set 8 | sidi ali
# Processing Record 35 of Set 8 | tulun
# Processing Record 36 of Set 8 | marsh harbour
# Processing Record 37 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 8 | merced
# Processing Record 39 of Set 8 | mogadishu
# Processing Record 40 of Set 8 | kununurra
# Processing Record 41 of Set 8 | tura
# Processing Record 42 of Set 8 | boshnyakovo
# Processing Record 43 of Set 8 | wajir
# Processing Record 44 of Set 8 | fort portal
# Processing Record 45 of Set 8 | lagoa
# Processing Record 46 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 8 | taloda
# Processing Record 48 of Set 8 | la ronge
# Processing Record 49 of Set 8 | ranot
# Processing Record 50 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 9 | alice springs
# Processing Record 2 of Set 9 | eyrarbakki
# Processing Record 3 of Set 9 | hay river
# Processing Record 4 of Set 9 | coihaique
# Processing Record 5 of Set 9 | umm kaddadah
# Processing Record 6 of Set 9 | dakar
# Processing Record 7 of Set 9 | kieta
# Processing Record 8 of Set 9 | lodja
# Processing Record 9 of Set 9 | portland
# Processing Record 10 of Set 9 | acajutla
# Processing Record 11 of Set 9 | carlyle
# Processing Record 12 of Set 9 | mayor pablo lagerenza
# Processing Record 13 of Set 9 | ruidoso
# Processing Record 14 of Set 9 | poum
# Processing Record 15 of Set 9 | bara
# Processing Record 16 of Set 9 | kloulklubed
# Processing Record 17 of Set 9 | kaeo
# Processing Record 18 of Set 9 | camp verde
# Processing Record 19 of Set 9 | gat
# Processing Record 20 of Set 9 | parrita
# Processing Record 21 of Set 9 | kavaratti
# Processing Record 22 of Set 9 | sitka
# Processing Record 23 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 24 of Set 9 | areosa
# Processing Record 25 of Set 9 | alihe
# Processing Record 26 of Set 9 | pangnirtung
# Processing Record 27 of Set 9 | kaitangata
# Processing Record 28 of Set 9 | victoria
# Processing Record 29 of Set 9 | pombas
# Processing Record 30 of Set 9 | shu
# Processing Record 31 of Set 9 | codrington
# Processing Record 32 of Set 9 | kongolo
# Processing Record 33 of Set 9 | iguape
# Processing Record 34 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 35 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 36 of Set 9 | boa vista
# Processing Record 37 of Set 9 | ichinohe
# Processing Record 38 of Set 9 | youghal
# Processing Record 39 of Set 9 | itarema
# Processing Record 40 of Set 9 | mayo
# Processing Record 41 of Set 9 | tarakan
# Processing Record 42 of Set 9 | teya
# Processing Record 43 of Set 9 | tagusao
# Processing Record 44 of Set 9 | bowen
# Processing Record 45 of Set 9 | lasa
# Processing Record 46 of Set 9 | laguna
# Processing Record 47 of Set 9 | saint-pierre
# Processing Record 48 of Set 9 | roald
# Processing Record 49 of Set 9 | am timan
# Processing Record 50 of Set 9 | itambacuri
# Processing Record 1 of Set 10 | miri
# Processing Record 2 of Set 10 | dovolnoye
# Processing Record 3 of Set 10 | penticton
# Processing Record 4 of Set 10 | alofi
# Processing Record 5 of Set 10 | jadu
# Processing Record 6 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 10 | sioux lookout
# Processing Record 8 of Set 10 | komsomolskiy
# Processing Record 9 of Set 10 | kulhudhuffushi
# Processing Record 10 of Set 10 | berlevag
# Processing Record 11 of Set 10 | jacksonville
# Processing Record 12 of Set 10 | hamilton
# Processing Record 13 of Set 10 | westport
# Processing Record 14 of Set 10 | mahibadhoo
# Processing Record 15 of Set 10 | cidreira
# Processing Record 16 of Set 10 | vizinga
# Processing Record 17 of Set 10 | bintulu
# Processing Record 18 of Set 10 | dalbandin
# Processing Record 19 of Set 10 | gouyave
# Processing Record 20 of Set 10 | jiujiang
# Processing Record 21 of Set 10 | killybegs
# Processing Record 22 of Set 10 | bambous virieux
# Processing Record 23 of Set 10 | burnie
# Processing Record 24 of Set 10 | kurilsk
# Processing Record 25 of Set 10 | lyskovo
# Processing Record 26 of Set 10 | talnakh
# Processing Record 27 of Set 10 | egvekinot
# Processing Record 28 of Set 10 | phan thiet
# Processing Record 29 of Set 10 | grakhovo
# Processing Record 30 of Set 10 | yulara
# Processing Record 31 of Set 10 | berdigestyakh
# Processing Record 32 of Set 10 | correntina
# Processing Record 33 of Set 10 | coahuayana
# Processing Record 34 of Set 10 | puerto cabezas
# Processing Record 35 of Set 10 | brooks
# Processing Record 36 of Set 10 | royan
# Processing Record 37 of Set 10 | yingzhong
# City not found. Skipping...
# Processing Record 38 of Set 10 | chalus
# Processing Record 39 of Set 10 | broken hill
# Processing Record 40 of Set 10 | rio gallegos
# Processing Record 41 of Set 10 | manaure
# Processing Record 42 of Set 10 | farcasa
# Processing Record 43 of Set 10 | evensk
# Processing Record 44 of Set 10 | harper
# Processing Record 45 of Set 10 | salinopolis
# Processing Record 46 of Set 10 | elban
# Processing Record 47 of Set 10 | saskylakh
# Processing Record 48 of Set 10 | kozelsk
# Processing Record 49 of Set 10 | macae
# Processing Record 50 of Set 10 | saint anthony
# Processing Record 1 of Set 11 | comodoro rivadavia
# Processing Record 2 of Set 11 | novyy urengoy
# Processing Record 3 of Set 11 | henties bay
# Processing Record 4 of Set 11 | belint
# Processing Record 5 of Set 11 | rassvet
# Processing Record 6 of Set 11 | usinsk
# Processing Record 7 of Set 11 | mumford
# Processing Record 8 of Set 11 | caluquembe
# Processing Record 9 of Set 11 | honiara
# Processing Record 10 of Set 11 | asekeyevo
# Processing Record 11 of Set 11 | pisco
# Processing Record 12 of Set 11 | ust-kut
# Processing Record 13 of Set 11 | sabha
# Processing Record 14 of Set 11 | ratnagiri
# Processing Record 15 of Set 11 | gorele
# Processing Record 16 of Set 11 | sao joao da barra
# Processing Record 17 of Set 11 | pale
# Processing Record 18 of Set 11 | asyut
# Processing Record 19 of Set 11 | lipari
# Processing Record 20 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 11 | kefamenanu
# Processing Record 22 of Set 11 | mitu
# Processing Record 23 of Set 11 | lishui
# Processing Record 24 of Set 11 | ostrovnoy
# Processing Record 25 of Set 11 | perustica
# City not found. Skipping...
# Processing Record 26 of Set 11 | matara
# Processing Record 27 of Set 11 | longhua
# Processing Record 28 of Set 11 | hami
# Processing Record 29 of Set 11 | gorin
# Processing Record 30 of Set 11 | oistins
# Processing Record 31 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 32 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 11 | kalmunai
# Processing Record 34 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 11 | sume
# Processing Record 36 of Set 11 | vestmannaeyjar
# Processing Record 37 of Set 11 | nhulunbuy
# Processing Record 38 of Set 11 | pringsewu
# Processing Record 39 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 40 of Set 11 | luena
# Processing Record 41 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 42 of Set 11 | sooke
# Processing Record 43 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 44 of Set 11 | olavarria
# Processing Record 45 of Set 11 | cherdyn
# Processing Record 46 of Set 11 | mbeya
# Processing Record 47 of Set 11 | korla
# Processing Record 48 of Set 11 | adre
# Processing Record 49 of Set 11 | rincon
# Processing Record 50 of Set 11 | san jeronimo
# Processing Record 1 of Set 12 | bacuit
# City not found. Skipping...
# Processing Record 2 of Set 12 | zabol
# Processing Record 3 of Set 12 | ossora
# Processing Record 4 of Set 12 | kayseri
# Processing Record 5 of Set 12 | jiangyou
# Processing Record 6 of Set 12 | mosquera
# Processing Record 7 of Set 12 | jiayuguan
# Processing Record 8 of Set 12 | omsukchan
# Processing Record 9 of Set 12 | uddevalla
# Processing Record 10 of Set 12 | fort abbas
# Processing Record 11 of Set 12 | ust-maya
# Processing Record 12 of Set 12 | colonia
# Processing Record 13 of Set 12 | san cristobal
# Processing Record 14 of Set 12 | abay
# Processing Record 15 of Set 12 | tanout
# Processing Record 16 of Set 12 | viedma
# Processing Record 17 of Set 12 | abu samrah
# Processing Record 18 of Set 12 | moron
# Processing Record 19 of Set 12 | yelizovo
# Processing Record 20 of Set 12 | conceicao do almeida
# Processing Record 21 of Set 12 | nuuk
# Processing Record 22 of Set 12 | klyuchi
# Processing Record 23 of Set 12 | andenes
# Processing Record 24 of Set 12 | nouna
# Processing Record 25 of Set 12 | mapiri
# Processing Record 26 of Set 12 | padang
# Processing Record 27 of Set 12 | magdalena
# Processing Record 28 of Set 12 | male
# Processing Record 29 of Set 12 | hofn
# Processing Record 30 of Set 12 | beloha
# Processing Record 31 of Set 12 | cocobeach
# Processing Record 32 of Set 12 | marrakesh
# Processing Record 33 of Set 12 | vostok
# Processing Record 34 of Set 12 | rio grande
# Processing Record 35 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 12 | fare
# Processing Record 37 of Set 12 | chateaubelair
# Processing Record 38 of Set 12 | banjarmasin
# Processing Record 39 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 40 of Set 12 | matagami
# Processing Record 41 of Set 12 | leua
# Processing Record 42 of Set 12 | jamsa
# Processing Record 43 of Set 12 | savannah bight
# Processing Record 44 of Set 12 | sangmelima
# Processing Record 45 of Set 12 | ipixuna
# Processing Record 46 of Set 12 | douglas
# Processing Record 47 of Set 12 | dingli
# Processing Record 48 of Set 12 | ilulissat
# Processing Record 49 of Set 12 | feijo
# Processing Record 50 of Set 12 | tautira
# Processing Record 1 of Set 13 | agadez
# Processing Record 2 of Set 13 | alvaraes
# Processing Record 3 of Set 13 | didao
# Processing Record 4 of Set 13 | kushima
# Processing Record 5 of Set 13 | lakes entrance
# Processing Record 6 of Set 13 | grand gaube
# Processing Record 7 of Set 13 | puerto baquerizo moreno
# Processing Record 8 of Set 13 | garden city
# Processing Record 9 of Set 13 | malaya serdoba
# Processing Record 10 of Set 13 | waipawa
# Processing Record 11 of Set 13 | pio ix
# Processing Record 12 of Set 13 | sakakah
# Processing Record 13 of Set 13 | suhbaatar
# Processing Record 14 of Set 13 | iqaluit
# Processing Record 15 of Set 13 | samut sakhon
# Processing Record 16 of Set 13 | sobolevo
# Processing Record 17 of Set 13 | chesma
# Processing Record 18 of Set 13 | axixa do tocantins
# City not found. Skipping...
# Processing Record 19 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 20 of Set 13 | quixere
# Processing Record 21 of Set 13 | mezen
# Processing Record 22 of Set 13 | le vauclin
# Processing Record 23 of Set 13 | port lincoln
# Processing Record 24 of Set 13 | husavik
# Processing Record 25 of Set 13 | itauna
# Processing Record 26 of Set 13 | southbridge
# Processing Record 27 of Set 13 | soanierana ivongo
# Processing Record 28 of Set 13 | at-bashi
# Processing Record 29 of Set 13 | sistranda
# Processing Record 30 of Set 13 | cabedelo
# Processing Record 31 of Set 13 | bumba
# Processing Record 32 of Set 13 | imbituba
# Processing Record 33 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 34 of Set 13 | mvomero
# Processing Record 35 of Set 13 | bilibino
# Processing Record 36 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 37 of Set 13 | madimba
# Processing Record 38 of Set 13 | muzhi
# Processing Record 39 of Set 13 | mapastepec
# Processing Record 40 of Set 13 | breves
# Processing Record 41 of Set 13 | akyab
# Processing Record 42 of Set 13 | reynosa
# Processing Record 43 of Set 13 | dwarka
# Processing Record 44 of Set 13 | sekondi
# Processing Record 45 of Set 13 | luan
# Processing Record 46 of Set 13 | tukrah
# Processing Record 47 of Set 13 | arona
# Processing Record 48 of Set 13 | hobyo
# Processing Record 49 of Set 13 | port hardy
# Processing Record 50 of Set 13 | alencon
# Processing Record 1 of Set 14 | ukiah
# Processing Record 2 of Set 14 | ajaccio
# Processing Record 3 of Set 14 | ambilobe
# Processing Record 4 of Set 14 | gushi
# Processing Record 5 of Set 14 | abbeville
# Processing Record 6 of Set 14 | yenagoa
# Processing Record 7 of Set 14 | puerto colombia
# Processing Record 8 of Set 14 | higuey
# City not found. Skipping...
# Processing Record 9 of Set 14 | port-gentil
# Processing Record 10 of Set 14 | cape coast
# Processing Record 11 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 12 of Set 14 | villazon
# Processing Record 13 of Set 14 | neepawa
# Processing Record 14 of Set 14 | yerbogachen
# Processing Record 15 of Set 14 | samarai
# Processing Record 16 of Set 14 | mardin
# Processing Record 17 of Set 14 | sao felix do xingu
# Processing Record 18 of Set 14 | prince rupert
# Processing Record 19 of Set 14 | yvetot
# Processing Record 20 of Set 14 | banjar
# Processing Record 21 of Set 14 | flin flon
# Processing Record 22 of Set 14 | rio bananal
# Processing Record 23 of Set 14 | avera
# Processing Record 24 of Set 14 | thinadhoo
# Processing Record 25 of Set 14 | oussouye
# Processing Record 26 of Set 14 | guatemalita
# City not found. Skipping...
# Processing Record 27 of Set 14 | luang prabang
# Processing Record 28 of Set 14 | hrubieszow
# Processing Record 29 of Set 14 | anzio
# Processing Record 30 of Set 14 | mantua
# Processing Record 31 of Set 14 | tahoua
# Processing Record 32 of Set 14 | port hedland
# Processing Record 33 of Set 14 | myitkyina
# Processing Record 34 of Set 14 | carberry
# Processing Record 35 of Set 14 | fougamou
# Processing Record 36 of Set 14 | kuytun
# Processing Record 37 of Set 14 | gatehouse of fleet
# Processing Record 38 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 39 of Set 14 | leh
# Processing Record 40 of Set 14 | jalu
# Processing Record 41 of Set 14 | lumby
# Processing Record 42 of Set 14 | baykit
# Processing Record 43 of Set 14 | jiaozuo
# Processing Record 44 of Set 14 | skibbereen
# Processing Record 45 of Set 14 | balkanabat
# Processing Record 46 of Set 14 | antalaha
# Processing Record 47 of Set 14 | siilinjarvi
# Processing Record 48 of Set 14 | feicheng
# Processing Record 49 of Set 14 | buon me thuot
# City not found. Skipping...
# Processing Record 50 of Set 14 | peniche
# Processing Record 1 of Set 15 | obo
# Processing Record 2 of Set 15 | fort saint james
# Processing Record 3 of Set 15 | paka
# Processing Record 4 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 5 of Set 15 | aranos
# Processing Record 6 of Set 15 | cascais
# Processing Record 7 of Set 15 | ada
# Processing Record 8 of Set 15 | san cosme y damian
# Processing Record 9 of Set 15 | chico
# Processing Record 10 of Set 15 | picton
# Processing Record 11 of Set 15 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 12 of Set 15 | pietarsaari
# Processing Record 13 of Set 15 | katherine
# Processing Record 14 of Set 15 | petrolina de goias
# Processing Record 15 of Set 15 | belyy yar
# Processing Record 16 of Set 15 | callaway
# Processing Record 17 of Set 15 | maceio
# Processing Record 18 of Set 15 | nara
# Processing Record 19 of Set 15 | valdivia
# Processing Record 20 of Set 15 | santa maria
# Processing Record 21 of Set 15 | tilichiki
# Processing Record 22 of Set 15 | auki
# Processing Record 23 of Set 15 | taoudenni
# Processing Record 24 of Set 15 | jian
# Processing Record 25 of Set 15 | san pedro de lloc
# Processing Record 26 of Set 15 | yumen
# Processing Record 27 of Set 15 | khuzhir
# Processing Record 28 of Set 15 | dauphin
# Processing Record 29 of Set 15 | finschhafen
# Processing Record 30 of Set 15 | bembereke
# Processing Record 31 of Set 15 | sabang
# Processing Record 32 of Set 15 | okhotsk
# Processing Record 33 of Set 15 | smithers
# Processing Record 34 of Set 15 | matay
# Processing Record 35 of Set 15 | san joaquin
# Processing Record 36 of Set 15 | tibiri
# Processing Record 37 of Set 15 | misratah
# Processing Record 38 of Set 15 | rognan
# Processing Record 39 of Set 15 | tirthahalli
# Processing Record 40 of Set 15 | mae chan
# Processing Record 41 of Set 15 | betanzos
# Processing Record 42 of Set 15 | shankargarh
# Processing Record 43 of Set 15 | filadelfia
# Processing Record 44 of Set 15 | gizo
# Processing Record 45 of Set 15 | ust-nera
# Processing Record 46 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 15 | sajanan
# Processing Record 48 of Set 15 | budogoshch
# Processing Record 49 of Set 15 | shelburne
# Processing Record 50 of Set 15 | vagur
# Processing Record 1 of Set 16 | hanstholm
# Processing Record 2 of Set 16 | ferrol
# Processing Record 3 of Set 16 | pokhara
# Processing Record 4 of Set 16 | ishigaki
# Processing Record 5 of Set 16 | nanning
# Processing Record 6 of Set 16 | wellington
# Processing Record 7 of Set 16 | tiarei
# Processing Record 8 of Set 16 | donskoye
# Processing Record 9 of Set 16 | kamenka
# Processing Record 10 of Set 16 | amapala
# Processing Record 11 of Set 16 | coruripe
# Processing Record 12 of Set 16 | havoysund
# Processing Record 13 of Set 16 | ardakan
# Processing Record 14 of Set 16 | vanavara
# Processing Record 15 of Set 16 | puerto madryn
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea -23.1203 -134.9692     75.40        71         100
# 1      Yar-Sale  66.8333   70.8333     -8.81        90          44
# 2   Tuktoyaktuk  69.4541 -133.0374      5.00        78          20
# 3     Carnarvon -24.8667  113.6333     71.67        88          90
# 4   Port Alfred -33.5906   26.8910     67.48        74          74
# 5        Vanimo  -2.6741  141.3028     77.76        90         100
# 6  Punta Arenas -53.1500  -70.9167     51.91        46          40
# 7      Yangambi   0.8102   24.4336     71.76        97         100
# 8     Cape Town -33.9258   18.4232     65.26        75          20
# 9       Aklavik  68.2191 -135.0107     11.12        85          75
#
#    Wind Speed Country                 Date Current Description
# 0       22.79      PF  2021-12-07 18:37:54     overcast clouds
# 1        9.48      RU  2021-12-07 18:37:54    scattered clouds
# 2       10.36      CA  2021-12-07 18:37:55          few clouds
# 3        8.05      AU  2021-12-07 18:37:55     overcast clouds
# 4       14.94      ZA  2021-12-07 18:37:55       broken clouds
# 5        6.51      PG  2021-12-07 18:37:56     overcast clouds
# 6       35.68      CL  2021-12-07 18:37:56    scattered clouds
# 7        2.71      CD  2021-12-07 18:37:57     overcast clouds
# 8        8.99      ZA  2021-12-07 18:37:57          few clouds
# 9        3.44      CA  2021-12-07 18:37:57       broken clouds

# %%
#change column order (removed date from here...added current description above and here)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea      PF -23.1203 -134.9692     75.40        71         100
# 1      Yar-Sale      RU  66.8333   70.8333     -8.81        90          44
# 2   Tuktoyaktuk      CA  69.4541 -133.0374      5.00        78          20
# 3     Carnarvon      AU -24.8667  113.6333     71.67        88          90
# 4   Port Alfred      ZA -33.5906   26.8910     67.48        74          74
# 5        Vanimo      PG  -2.6741  141.3028     77.76        90         100
# 6  Punta Arenas      CL -53.1500  -70.9167     51.91        46          40
# 7      Yangambi      CD   0.8102   24.4336     71.76        97         100
# 8     Cape Town      ZA -33.9258   18.4232     65.26        75          20
# 9       Aklavik      CA  68.2191 -135.0107     11.12        85          75
#
#    Wind Speed Current Description
# 0       22.79     overcast clouds
# 1        9.48    scattered clouds
# 2       10.36          few clouds
# 3        8.05     overcast clouds
# 4       14.94       broken clouds
# 5        6.51     overcast clouds
# 6       35.68    scattered clouds
# 7        2.71     overcast clouds
# 8        8.99          few clouds
# 9        3.44       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
